# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = 5 * np.random.randn(10000) + 50
y = np.random.rand(10000)

# %%
X.std()
# Out:
# 5.009921936621735

# %%
plt.hist(X)
# Out:
# (array([  27.,  148.,  612., 1521., 2564., 2528., 1650.,  718.,  194.,
#           38.]),
#  array([32.62734927, 36.05938754, 39.4914258 , 42.92346407, 46.35550234,
#         49.7875406 , 53.21957887, 56.65161713, 60.0836554 , 63.51569367,
#         66.94773193]),
#  <a list of 10 Patch objects>)

# %%
print('Mean: ', X.mean())
print('Standard Deviation: ', X.std())
sns.distplot(data)
# Out:
# Mean:  50.030957961794584
# Standard Deviation:  5.009921936621735

# %%
plt.plot(X, '.')

# %% [markdown]
# # Finding the outliers

# %%
data_mean, data_std = X.mean(), X.std()

# %%
threshold = data_std*3; threshold
lower, upper = data_mean - threshold, data_mean + threshold
lower, upper
# Out:
# (35.00119215192938, 65.0607237716598)

# %%
outlier = [i for i in X if (i > upper) | (i<lower)]

# %%
len(outlier)
# Out:
# 28

# %%
new_data = [i for i in X if i >= lower and i<=upper]

# %%
plt.figure(figsize=(10,15))
plt.boxplot(X)
oulie
# Out:
# [51.070216446248274,
#  57.89235310707865,
#  42.754817123526095,
#  47.32363035160967,
#  49.96144122375515,
#  45.223724060785955,
#  63.54900891397392,
#  36.400750822188485,
#  56.30938703401331,
#  40.407316667029676,
#  54.43089944124311,
#  53.54052705798235,
#  53.71361268014597,
#  52.15030408672134,
#  43.10189622280231,
#  56.682374920752565,
#  48.58829108957148,
#  51.34205257115124,
#  43.957688307501776,
#  47.22084344098639,
#  47.57454753955507,
#  57.06892288118179,
#  48.469910543540806,
#  54.15570458880446,
#  43.06029717805303,
#  42.75562695005191,
#  59.80386654766757,
#  42.81900445086603,
#  45.04684870844802,
#  46.70723651511947,
#  45.28795219200208,
#  45.160602086524165,
#  55.227895558627566,
#  53.92904572893057,
#  47.882512617840284,
#  53.12078078264622,
#  53.662479066375084,
#  56.81271630775698,
#  49.1225967723529,
#  55.62324168544525,
#  57.87623295670713,
#  55.23719483626287,
#  48.92715468303055,
#  48.54407879906797,
#  46.8624338389951,
# ...

# %%
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11dcd90d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10f4c7210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x11de26f10>],
#  'medians': [<matplotlib.lines.Line2D at 0x11dcbc250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11dcc20d0>],
#  'means': []}
